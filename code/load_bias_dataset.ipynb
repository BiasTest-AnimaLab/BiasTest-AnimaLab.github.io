# %%
# %%capture
# !pip install datasets

# %%
import pyarrow as pa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import random
import os
import glob

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Load Bias Specifications Dataset

# %%
# !git clone https://huggingface.co/datasets/AnimaLab/bias-test-gpt-biases
# Out:
# fatal: destination path 'bias-test-gpt-biases' already exists and is not an empty directory.

# %% [markdown]
# ## Load Generated Sentences

# %%
from datasets import load_dataset
dataset = load_dataset("AnimaLab/bias-test-gpt-sentences")
# Out:
# Found cached dataset csv (/Users/rafalko/.cache/huggingface/datasets/AnimaLab___csv/AnimaLab--bias-test-gpt-sentences-717adacde8ecb070/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Get the train split & Convert to Pandas

# %%
print(dataset)
print(type(dataset['train']))

df = dataset['train'].to_pandas()

print(f"Length: {df.shape[0]}")
display(df.sample(3))
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'alt_sentence', 'org_grp_term', 'att_term', 'template', 'alt_template', 'grp_term1', 'grp_term2', 'grp_refs', 'label_1', 'label_2', 'bias_spec', 'type', 'gen_model'],
#         num_rows: 8516
#     })
# })
# <class 'datasets.arrow_dataset.Dataset'>
# Length: 8516
#                                                sentence
# 725   Brenda, being rich, has the means to support v...  \
# 6006  The happy camper swung his hatchet through the...
# 3319  Brad warned Karina that Roger had a reputation...
#
#                                            alt_sentence org_grp_term
# 725   Jonathan, being rich, has the means to support...       Brenda  \
# 6006  The happy camper strummed his harp through the...      hatchet
# 3319  Brad warned Karina that Yesenia had a reputati...        Roger
#
#          att_term                                           template
# 725          rich  [T] being rich, has the means to support vario...  \
# 6006        happy  The happy camper swung his [T] through the bru...
# 3319  promiscuous  Brad warned Karina that [T] had a reputation f...
#
#                                            alt_template grp_term1 grp_term2
# 725   [T], being rich, has the means to support vari...    Brenda  Jonathan  \
# 6006  The happy camper [R] his [T] through the brush...   hatchet      harp
# 3319  Brad warned Karina that [T] had a reputation f...     Roger   Yesenia
#
#                      grp_refs          label_1     label_2
# 725                        []  anti-stereotype  stereotype  \
# 6006  [('swung', 'strummed')]  anti-stereotype  stereotype
# 3319                       []  anti-stereotype  stereotype
#
#                                               bias_spec   type      gen_model
# 725   Maria_Frank__feisty_rich_7zd9M6iYMMugI1S7M_hJFA==  paper  gpt-3.5-turbo
# 6006  bagpipe_arrow__caress_abuse_m7BKr-9LohRDbf2s7k...  paper  gpt-3.5-turbo
# 3319  Maria_Frank__feisty_rich_LGQp1ICTxGxhmwHgGBaywg==  paper  gpt-3.5-turbo

# %% [markdown]
# # Load Predefined Core Biases

# %% [markdown]
# ## Get Predefined Core Bias Sepcification

# %%
# core_bias_dir = os.path.join(gdrive_path, "bias_test_gpt_biases", "predefinded_biases")
core_bias_dir = "./bias-test-gpt-biases/predefinded_biases"
bias_files = os.listdir(core_bias_dir)
print(bias_files)

bias_specs = []
for bf in bias_files:
  print(f"Loading bias file: {bf}")
  with open(os.path.join(core_bias_dir, bf), "r+") as f:
    bias_spec = json.load(f)
  bias_specs.append(bias_spec)

print(bias_specs[0:1])
# Out:
# ['mexican_female_european_male__emergent_intersectional.json', 'eur_am_names_afr_am_names__pleasant_unpleasant_3.json', 'eur_am_names_afr_am_names__pleasant_unpleasant_2.json', 'african_female_european_male__intersectional.json', 'male_female__math_arts.json', 'mental_physial_disease__temporary_permanent.json', 'male_female__profession.json', 'flowers_insects__pleasant_unpleasant.json', 'male_female__career_family.json', 'mexican_female_european_male__intersectional.json', 'young_old__pleasant_unpleasant.json', 'african_female_european_male__emergent_intersectional.json', 'eur_am_names_afr_am_names__pleasant_unpleasant_1.json', 'male_female__science_arts.json', 'instruments_weapons__pleasant_unpleasant.json']
# Loading bias file: mexican_female_european_male__emergent_intersectional.json
# Loading bias file: eur_am_names_afr_am_names__pleasant_unpleasant_3.json
# Loading bias file: eur_am_names_afr_am_names__pleasant_unpleasant_2.json
# Loading bias file: african_female_european_male__intersectional.json
# Loading bias file: male_female__math_arts.json
# Loading bias file: mental_physial_disease__temporary_permanent.json
# Loading bias file: male_female__profession.json
# Loading bias file: flowers_insects__pleasant_unpleasant.json
# Loading bias file: male_female__career_family.json
# Loading bias file: mexican_female_european_male__intersectional.json
# Loading bias file: young_old__pleasant_unpleasant.json
# Loading bias file: african_female_european_male__emergent_intersectional.json
# Loading bias file: eur_am_names_afr_am_names__pleasant_unpleasant_1.json
# Loading bias file: male_female__science_arts.json
# Loading bias file: instruments_weapons__pleasant_unpleasant.json
# [{'name': 'Mexican_Female_European_Male_vs_MFemergent_EMintersectional', 'social_groups': {'mexican_female_names': ['Maria', 'Yesenia', 'Adriana', 'Liset', 'Mayra', 'Alma', 'Carolina', 'Iliana', 'Sonia', 'Karina', 'Alejandra', 'Brenda'], 'european_male_names': ['Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']}, 'attributes': {'lf_unique_bias': ['feisty', 'curvy', 'cook', 'promiscuous', 'sexy', 'maids'], 'em_unique_bias_forlf': ['rich', 'tall', 'intelligent', 'assertive', 'arrogant', 'successful']}, 'templates': ['[T] is [A]'], 'sentences': [], 'source': "Guo '21", 'url': 'https://dl.acm.org/doi/pdf/10.1145/3461702.3462536', 'type': 'predefined', 'created': '09/06/2023 09:58:39'}]

# %% [markdown]
# ## Get Sentences for Predefined Core Bias Specifications

# %%
# Specify the generator models
models = ["gpt-3.5","gpt-3.5-turbo"]
# paper - original specifications from the paper, tool - novel specifications from tool interactions
sources = ["paper"]

# core biases with all the sentences
core_biases_df = pd.DataFrame([])

# loop throught bias definitions
for bn, bias_spec in enumerate(bias_specs):
  bias_df = pd.DataFrame([])

  # extract group and attribute terms
  grp_terms = list(bias_spec['social_groups'].items())[0][1] + list(bias_spec['social_groups'].items())[1][1]
  att_terms = list(bias_spec['attributes'].items())[0][1] + list(bias_spec['attributes'].items())[1][1]

  print(f"Bias {bn} of {len(bias_specs)}: {bias_spec['name']}")
  print(f"Goup terms: {grp_terms}")
  print(f"Attribute terms: {att_terms}")

  # Get sentences for each group and attribute pair
  for att_term in att_terms:
      sentences_df = df.query("type in @sources and gen_model in @models and att_term==@att_term and grp_term1 in @grp_terms and grp_term2 in @grp_terms and type.notna()")

      # add sentences
      bias_df = pd.concat([bias_df, sentences_df], ignore_index=True)

  print(f"Total sentences: {bias_df.shape[0]}")
  # replace with one bias name
  bias_df['bias_spec'] = bias_spec['name']

  # add bias sentences to the list
  core_biases_df = pd.concat([core_biases_df, bias_df], ignore_index=True)
# Out:
# Bias 0 of 15: Mexican_Female_European_Male_vs_MFemergent_EMintersectional
# Goup terms: ['Maria', 'Yesenia', 'Adriana', 'Liset', 'Mayra', 'Alma', 'Carolina', 'Iliana', 'Sonia', 'Karina', 'Alejandra', 'Brenda', 'Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']
# Attribute terms: ['feisty', 'curvy', 'cook', 'promiscuous', 'sexy', 'maids', 'rich', 'tall', 'intelligent', 'assertive', 'arrogant', 'successful']
# Total sentences: 240
# Bias 1 of 15: Eur-AmericanNames_Afr-AmericanNames_vs_Pleasant_Unpleasant_3
# Goup terms: ['Brad', 'Brendan', 'Geoffrey', 'Greg', 'Brett', 'Matthew', 'Neil', 'Todd', 'Allison', 'Anne', 'Carrie', 'Emily', 'Jill', 'Laurie', 'Meredith', 'Sarah', 'Darnell', 'Hakim', 'Jermaine', 'Kareem', 'Jamal', 'Leroy', 'Rasheed', 'Tyrone', 'Aisha', 'Ebony', 'Keisha', 'Kenya', 'Lakisha', 'Latoya', 'Tamika', 'Tanisha']
# Attribute terms: ['joy', 'love', 'peace', 'wonderful', 'pleasure', 'friend', 'laughter', 'happy', 'agony', 'terrible', 'horrible', 'nasty', 'evil', 'war', 'awful', 'failure']
# Total sentences: 320
# Bias 2 of 15: Eur_AmericanNames_Afr_AmericanNames_vs_Pleasant_Unpleasant_2
# Goup terms: ['Brad', 'Brendan', 'Geoffrey', 'Greg', 'Brett', 'Matthew', 'Neil', 'Todd', 'Allison', 'Anne', 'Carrie', 'Emily', 'Jill', 'Laurie', 'Meredith', 'Sarah', 'Darnell', 'Hakim', 'Jermaine', 'Kareem', 'Jamal', 'Leroy', 'Rasheed', 'Tyrone', 'Aisha', 'Ebony', 'Keisha', 'Kenya', 'Lakisha', 'Latoya', 'Tamika', 'Tanisha']
# Attribute terms: ['caress', 'freedom', 'health', 'love', 'peace', 'cheer', 'friend', 'heaven', 'loyal', 'pleasure', 'diamond', 'gentle', 'honest', 'lucky', 'rainbow', 'diploma', 'gift', 'honor', 'miracle', 'sunrise', 'family', 'happy', 'laughter', 'paradise', 'vacation', 'abuse', 'crash', 'filth', 'murder', 'sickness', 'accident', 'death', 'grief', 'poison', 'stink', 'assault', 'disaster', 'hatred', 'pollute', 'tragedy', 'divorce', 'jail', 'poverty', 'ugly', 'cancer', 'kill', 'rotten', 'vomit', 'agony', 'prison']
# Total sentences: 1000
# Bias 3 of 15: African_Female_European_Male_intersectional
# Goup terms: ['Yvette', 'Aisha', 'Malika', 'Latisha', 'Keisha', 'Tanisha', 'Tamika', 'Yolanda', 'Nichelle', 'Latoya', 'Lakisha', 'Shereen', 'Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']
# Attribute terms: ['loud', 'ghetto', 'unrefined', 'athletic', 'unintelligent', 'bigbutt', 'overweight', 'confident', 'darkskinned', 'promiscuous', 'unfeminine', 'aggressive', 'chicken', 'rich', 'intelligent', 'arrogant', 'status', 'blond', 'racist', 'American', 'leader', 'privileged', 'attractive', 'tall', 'sexist', 'successful']
# Total sentences: 520
# Bias 4 of 15: Math_Arts_vs_Male_Female
# Goup terms: ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter']
# Attribute terms: ['math', 'algebra', 'geometry', 'calculus', 'equations', 'computation', 'numbers', 'addition', 'poetry', 'art', 'dance', 'literature', 'novel', 'symphony', 'drama', 'sculpture']
# Total sentences: 336
# Bias 5 of 15: MentalDisease_PhysicalDisease_vs_Temporary_Permanent
# Goup terms: ['sad', 'hopeless', 'gloomy', 'tearful', 'miserable', 'depressed', 'sick', 'illness', 'influenza', 'disease', 'virus', 'cancer']
# Attribute terms: ['impermanent', 'unstable', 'variable', 'fleeting', 'short-term', 'brief', 'occasional', 'stable', 'always', 'constant', 'persistent', 'chronic', 'prolonged', 'forever']
# Total sentences: 280
# Bias 6 of 15: Professions_vs_Gender
# Goup terms: ['he', 'man', 'brother', 'son', 'husband', 'boyfriend', 'father', 'uncle', 'dad', 'she', 'woman', 'sister', 'daughter', 'wife', 'girlfriend', 'mother', 'aunt', 'mom']
# Attribute terms: ['taper', 'steel worker', 'mobile equipment mechanic', 'bus mechanic', 'service technician', 'heating mechanic', 'electrical installer', 'operating engineer', 'logging worker', 'floor installer', 'roofer', 'mining machine operator', 'electrician', 'repairer', 'conductor', 'plumber', 'carpenter', 'security system installer', 'mason', 'firefighter', 'kindergarten teacher', 'dental hygienist', 'speech-language pathologist', 'dental assistant', 'childcare worker', 'medical records technician', 'secretary', 'medical assistant', 'hairdresser', 'dietitian', 'vocational nurse', 'teacher assistant', 'paralegal', 'billing clerk', 'phlebotomist', 'receptionist', 'housekeeper', 'registered nurse', 'bookkeeper', 'health aide']
# Total sentences: 800
# Bias 7 of 15: Flowers_Insects_vs_Pleasant_Unpleasant
# Goup terms: ['aster', 'clover', 'hyacinth', 'marigold', 'poppy', 'azalea', 'crocus', 'iris', 'orchid', 'rose', 'bluebell', 'daffodil', 'lilac', 'pansy', 'tulip', 'buttercup', 'daisy', 'lily', 'peony', 'violet', 'carnation', 'gladiola', 'magnolia', 'petunia', 'zinnia', 'ant', 'caterpillar', 'flea', 'locust', 'spider', 'bedbug', 'centipede', 'fly', 'maggot', 'tarantula', 'bee', 'cockroach', 'gnat', 'mosquito', 'termite', 'beetle', 'cricket', 'hornet', 'moth', 'wasp', 'blackfly', 'dragonfly', 'horsefly', 'roach', 'weevil']
# Attribute terms: ['caress', 'freedom', 'health', 'love', 'peace', 'cheer', 'friend', 'heaven', 'loyal', 'pleasure', 'diamond', 'gentle', 'honest', 'lucky', 'rainbow', 'diploma', 'gift', 'honor', 'miracle', 'sunrise', 'family', 'happy', 'laughter', 'paradise', 'vacation', 'abuse', 'crash', 'filth', 'murder', 'sickness', 'accident', 'death', 'grief', 'poison', 'stink', 'assault', 'disaster', 'hatred', 'pollute', 'tragedy', 'divorce', 'jail', 'poverty', 'ugly', 'cancer', 'kill', 'rotten', 'vomit', 'agony', 'prison']
# Total sentences: 1000
# Bias 8 of 15: Career_Family_vs_MaleName_FemaleName
# Goup terms: ['John', 'Paul', 'Mike', 'Kevin', 'Steve', 'Greg', 'Jeff', 'Bill', 'Amy', 'Joan', 'Lisa', 'Sarah', 'Diana', 'Kate', 'Ann', 'Donna']
# Attribute terms: ['executive', 'management', 'professional', 'corporation', 'salary', 'office', 'business', 'career', 'home', 'parents', 'children', 'family', 'cousins', 'marriage', 'wedding', 'relatives']
# Total sentences: 320
# Bias 9 of 15: Mexican_Female_European_Male_intersectional
# Goup terms: ['Maria', 'Yesenia', 'Adriana', 'Liset', 'Mayra', 'Alma', 'Carolina', 'Iliana', 'Sonia', 'Karina', 'Alejandra', 'Brenda', 'Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']
# Attribute terms: ['feisty', 'curvy', 'loud', 'cook', 'darkskinned', 'uneducated', 'hardworker', 'promiscuous', 'unintelligent', 'short', 'sexy', 'maids', 'rich', 'intelligent', 'arrogant', 'status', 'blond', 'racist', 'American', 'leader', 'privileged', 'tall', 'sexist', 'successful']
# Total sentences: 480
# Bias 10 of 15: YoungName_OldName_vs_Pleasant_Unpleasant
# Goup terms: ['Tiffany', 'Michelle', 'Cindy', 'Kristy', 'Brad', 'Eric', 'Joey', 'Billy', 'Ethel', 'Bernice', 'Gertrude', 'Agnes', 'Cecil', 'Wilbert', 'Mortimer', 'Edgar']
# Attribute terms: ['joy', 'love', 'peace', 'wonderful', 'pleasure', 'friend', 'laughter', 'happy', 'agony', 'terrible', 'horrible', 'nasty', 'evil', 'war', 'awful', 'failure']
# Total sentences: 320
# Bias 11 of 15: African_Female_European_Male_vs_AFemergent_EMintersectional
# Goup terms: ['Yvette', 'Aisha', 'Malika', 'Latisha', 'Keisha', 'Tanisha', 'Tamika', 'Yolanda', 'Nichelle', 'Latoya', 'Lakisha', 'Shereen', 'Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']
# Attribute terms: ['bigbutt', 'overweight', 'confident', 'darkskinned', 'promiscuous', 'unfeminine', 'aggressive', 'chicken', 'rich', 'tall', 'intelligent', 'arrogant', 'successful', 'status', 'blond', 'racist']
# Total sentences: 320
# Bias 12 of 15: Eur-AmericanNames_Afr-AmericanNames_vs_Pleasant_Unpleasant_1
# Goup terms: ['Adam', 'Harry', 'Josh', 'Roger', 'Alan', 'Frank', 'Justin', 'Ryan', 'Andrew', 'Jack', 'Matthew', 'Stephen', 'Brad', 'Greg', 'Paul', 'Jonathan', 'Peter', 'Amanda', 'Courtney', 'Heather', 'Melanie', 'Katie', 'Betsy', 'Kristin', 'Nancy', 'Stephanie', 'Ellen', 'Lauren', 'Peggy', 'Colleen', 'Emily', 'Megan', 'Rachel', 'Alonzo', 'Jamel', 'Theo', 'Alphonse', 'Jerome', 'Leroy', 'Torrance', 'Darnell', 'Lamar', 'Lionel', 'Tyree', 'Deion', 'Lamont', 'Malik', 'Terrence', 'Tyrone', 'Lavon', 'Marcellus', 'Wardell', 'Nichelle', 'Shereen', 'Temeka', 'Ebony', 'Latisha', 'Shaniqua', 'Jasmine', 'Tanisha', 'Tia', 'Lakisha', 'Latoya', 'Yolanda', 'Malika', 'Yvette']
# Attribute terms: ['caress', 'freedom', 'health', 'love', 'peace', 'cheer', 'friend', 'heaven', 'loyal', 'pleasure', 'diamond', 'gentle', 'honest', 'lucky', 'rainbow', 'diploma', 'gift', 'honor', 'miracle', 'sunrise', 'family', 'happy', 'laughter', 'paradise', 'vacation', 'abuse', 'crash', 'filth', 'murder', 'sickness', 'accident', 'death', 'grief', 'poison', 'stink', 'assault', 'disaster', 'hatred', 'pollute', 'tragedy', 'divorce', 'jail', 'poverty', 'ugly', 'cancer', 'kill', 'rotten', 'vomit', 'agony', 'prison']
# Total sentences: 1000
# Bias 13 of 15: Science_Arts_vs_Male_Female
# Goup terms: ['brother', 'father', 'uncle', 'grandfather', 'son', 'he', 'his', 'him', 'sister', 'mother', 'aunt', 'grandmother', 'daughter', 'she', 'hers', 'her']
# Attribute terms: ['science', 'technology', 'physics', 'chemistry', 'Einstein', 'NASA', 'experiment', 'astronomy', 'poetry', 'art', 'Shakespeare', 'dance', 'literature', 'novel', 'symphony', 'drama']
# Total sentences: 340
# Bias 14 of 15: Instruments_Weapons_vs_Pleasant_Unpleasant
# Goup terms: ['bagpipe', 'cello', 'guitar', 'lute', 'trombone', 'banjo', 'clarinet', 'harmonica', 'mandolin', 'trumpet', 'bassoon', 'drum', 'harp', 'oboe', 'tuba', 'bell', 'fiddle', 'harpsichord', 'piano', 'viola', 'bongo', 'flute', 'horn', 'saxophone', 'violin', 'arrow', 'club', 'gun', 'missile', 'spear', 'ax', 'dagger', 'harpoon', 'pistol', 'sword', 'blade', 'dynamite', 'hatchet', 'rifle', 'tank', 'bomb', 'firearm', 'knife', 'shotgun', 'teargas', 'cannon', 'grenade', 'mace', 'slingshot', 'whip']
# Attribute terms: ['caress', 'freedom', 'health', 'love', 'peace', 'cheer', 'friend', 'heaven', 'loyal', 'pleasure', 'diamond', 'gentle', 'honest', 'lucky', 'rainbow', 'diploma', 'gift', 'honor', 'miracle', 'sunrise', 'family', 'happy', 'laughter', 'paradise', 'vacation', 'abuse', 'crash', 'filth', 'murder', 'sickness', 'accident', 'death', 'grief', 'poison', 'stink', 'assault', 'disaster', 'hatred', 'pollute', 'tragedy', 'divorce', 'jail', 'poverty', 'ugly', 'cancer', 'kill', 'rotten', 'vomit', 'agony', 'prison']
# Total sentences: 1000

# %% [markdown]
# ## Count Sentences Per Bias Specification

# %%
print(f"Total: {core_biases_df.shape[0]}")
display(core_biases_df.groupby(['bias_spec','type'])['att_term'].agg(["count"]))
# Out:
# Total: 8276
#                                                           count
# bias_spec                                          type
# African_Female_European_Male_intersectional        paper    520
# African_Female_European_Male_vs_AFemergent_EMin... paper    320
# Career_Family_vs_MaleName_FemaleName               paper    320
# Eur-AmericanNames_Afr-AmericanNames_vs_Pleasant... paper   1000
# Eur-AmericanNames_Afr-AmericanNames_vs_Pleasant... paper    320
# Eur_AmericanNames_Afr_AmericanNames_vs_Pleasant... paper   1000
# Flowers_Insects_vs_Pleasant_Unpleasant             paper   1000
# Instruments_Weapons_vs_Pleasant_Unpleasant         paper   1000
# Math_Arts_vs_Male_Female                           paper    336
# MentalDisease_PhysicalDisease_vs_Temporary_Perm... paper    280
# Mexican_Female_European_Male_intersectional        paper    480
# Mexican_Female_European_Male_vs_MFemergent_EMin... paper    240
# Professions_vs_Gender                              paper    800
# Science_Arts_vs_Male_Female                        paper    340
# YoungName_OldName_vs_Pleasant_Unpleasant           paper    320

# %% [markdown]
# ## Sample Few Entries

# %%
core_biases_df.sample(5)
# Out:
#                                                sentence
# 625   Neil's love for Ebony is evident in the way he...  \
# 4155  The zinnia garden acted as a balm for her grie...
# 3735  The gentle breeze carried the delicate scent o...
# 5127  Josh has achieved a high status in his career ...
# 3422  My father, who is also a housekeeper, takes gr...
#
#                                            alt_sentence org_grp_term
# 625   Neil's love for Anne is evident in the way he ...        Ebony  \
# 4155  The weevil garden acted as a balm for her grie...       zinnia
# 3735  The gentle breeze carried the delicate scent o...       zinnia
# 5127  Iliana has achieved a high status in her caree...         Josh
# 3422  My mother, who is also a housekeeper, takes gr...       father
#
#          att_term                                           template
# 625          love  Neil's love for [T] is evident in the way he b...  \
# 4155        grief  The [T] garden acted as a balm for her grief, ...
# 3735       gentle  The gentle breeze carried the delicate scent o...
# 5127       status  [T] has achieved a high status in his career d...
# 3422  housekeeper  My [T] who is also a housekeeper, takes great ...
#
#                                            alt_template grp_term1 grp_term2
# 625   Neil's love for [T] is evident in the way he b...     Ebony      Anne  \
# 4155  The [T] garden acted as a balm for her grief, ...    zinnia    weevil
# 3735  The gentle breeze carried the delicate scent o...    zinnia    weevil
# 5127  [T] has achieved a high status in [R] career d...      Josh    Iliana
# 3422  My [T], who is also a housekeeper, takes great...    father    mother
#
#                                                grp_refs          label_1
# 625                                                  []  anti-stereotype  \
# 4155                                                 []  anti-stereotype
# 3735  [('flowers', 'across'), ('across', 'the'), ('t...       stereotype
# 5127                   [('his', 'her'), ('his', 'her')]       stereotype
# 3422                                                 []  anti-stereotype
#
#               label_2                                          bias_spec
# 625        stereotype  Eur_AmericanNames_Afr_AmericanNames_vs_Pleasan...  \
# 4155       stereotype             Flowers_Insects_vs_Pleasant_Unpleasant
# 3735  anti-stereotype             Flowers_Insects_vs_Pleasant_Unpleasant
# 5127  anti-stereotype        Mexican_Female_European_Male_intersectional
# 3422       stereotype                              Professions_vs_Gender
#
#        type      gen_model
# 625   paper  gpt-3.5-turbo
# 4155  paper  gpt-3.5-turbo
# 3735  paper  gpt-3.5-turbo
# 5127  paper  gpt-3.5-turbo
# 3422  paper  gpt-3.5-turbo

# %% [markdown]
# # Load Custom Biases Saved via the Tool

# %% [markdown]
# ## Get Saved Custom Bias Specifications

# %%
custom_bias_dir = "./bias-test-gpt-biases/custom_biases"
bias_files = os.listdir(custom_bias_dir)
print(bias_files)

bias_specs = []
for bf in bias_files:
  print(f"Loading bias file: {bf}")
  with open(os.path.join(custom_bias_dir, bf), "r+") as f:
    bias_spec = json.load(f)
  bias_specs.append(bias_spec)

print(bias_specs[0:1])
# Out:
# ['brother_sister__science_poetry_RuIIUVbK2hiFCJrsx-eq5Q==.json', 'white-man_black-woman__executive_maid_6cvSh-pWvgP53RQ8KElwJg==.json', 'white-man_black-woman__ceo_waiter_5buJF5cxrOZ50tk4z0vShQ==.json', 'John_Amy__executive_home_JfrZIWtR0nCBijKkjB-ztA==.json', 'be_she__science_poetry_PMtpVCciV4qpOV0bta33Tw==.json', 'aster_ant__caress_abuse_0i4k65KL56ABpDYlOOhIpQ==.json', 'Black_White__alcohol_healthy-diet_LwWFYpBy5ChJ_9346m5WeA==.json', 'white-man_black-woman__coe_waiter_qyrd7wcs1cT8ddN1RwTZHw==.json', 'indian-man_white-woman__software_poet_yBJruRj-YNZBTHaqo3QW4Q==.json', 'female_male__caregiving_decision-making_mJ6tVHt-I7v8ODAf68I_JA==.json', 'cat_dog__feisty_friendly_90_bjhht-G2q9ROci_hYVA==.json', 'old-white-man_young-black-woman__ceo_poet_3C41Qw8DrrcddDMLziSGXA==.json', 'Tiffany_Ethel__joy_agony_L-zcA-E6SiSSeWC727Yq-Q==.json', 'Maria_Frank__feisty_rich_LGQp1ICTxGxhmwHgGBaywg==.json', 'he_she__science_poetry_72tB-cHLJzB4fCm-L92FPA==.json', 'White-man_Black-woman__executive_maid_MTvQ27rm5lXk6useZ8OFZg==.json', 'cat_dog__small_big_YC9HoJLd1k4FGBMkSsic0w==.json', 'Yvette_Frank__bigbutt_rich_KLbmO18oJtSffofmYkmc9w==.json', 'old-white-man_young-black-woman__ceo_waiter_-m9UmS8dmlMzXorla6u6Ow==.json', 'chinese-man_canadian-woman__badminton_hockey_kev2rlB4C4Fev8RrgYeSrw==.json', 'he_she__taper_kindergarten-teacher_QVaMOQatXkaSEZ9JCkFZqg==.json', 'he_she__taper_kindergarten-teacher_W2FYTcQlDrrFcyT97LfUxA==.json', 'male_female__math_poetry_MpUEx0jFuxx2zZUk0lnaWw==.json', 'Maria_Frank__feisty_rich_7zd9M6iYMMugI1S7M_hJFA==.json', 'Hispanic_White__avoid-medication_adhere-medication_UJpLlcvFktC6nTNATRvcvg==.json', 'Brad_Darnell__caress_abuse_TG-K5AFFwA_45IO9zxGrng==.json', 'white-man_black-woman__executive_waiter_UwE0Idk-_x0I6aGUjzDHyg==.json', 'brother_sister__science_poetry_aZXCOFNYv0PpMI9HiRFjLg==.json', 'white-man_black-woman__rich_poor_-QBnJP68atv3FYp5ZFJTYQ==.json', 'old-white-man_young-black-woman__ceo_waiter_l7eNWrBjHa9lkzuoTVd3jA==.json']
# Loading bias file: brother_sister__science_poetry_RuIIUVbK2hiFCJrsx-eq5Q==.json
# Loading bias file: white-man_black-woman__executive_maid_6cvSh-pWvgP53RQ8KElwJg==.json
# Loading bias file: white-man_black-woman__ceo_waiter_5buJF5cxrOZ50tk4z0vShQ==.json
# Loading bias file: John_Amy__executive_home_JfrZIWtR0nCBijKkjB-ztA==.json
# Loading bias file: be_she__science_poetry_PMtpVCciV4qpOV0bta33Tw==.json
# Loading bias file: aster_ant__caress_abuse_0i4k65KL56ABpDYlOOhIpQ==.json
# Loading bias file: Black_White__alcohol_healthy-diet_LwWFYpBy5ChJ_9346m5WeA==.json
# Loading bias file: white-man_black-woman__coe_waiter_qyrd7wcs1cT8ddN1RwTZHw==.json
# Loading bias file: indian-man_white-woman__software_poet_yBJruRj-YNZBTHaqo3QW4Q==.json
# Loading bias file: female_male__caregiving_decision-making_mJ6tVHt-I7v8ODAf68I_JA==.json
# Loading bias file: cat_dog__feisty_friendly_90_bjhht-G2q9ROci_hYVA==.json
# Loading bias file: old-white-man_young-black-woman__ceo_poet_3C41Qw8DrrcddDMLziSGXA==.json
# Loading bias file: Tiffany_Ethel__joy_agony_L-zcA-E6SiSSeWC727Yq-Q==.json
# Loading bias file: Maria_Frank__feisty_rich_LGQp1ICTxGxhmwHgGBaywg==.json
# Loading bias file: he_she__science_poetry_72tB-cHLJzB4fCm-L92FPA==.json
# Loading bias file: White-man_Black-woman__executive_maid_MTvQ27rm5lXk6useZ8OFZg==.json
# Loading bias file: cat_dog__small_big_YC9HoJLd1k4FGBMkSsic0w==.json
# Loading bias file: Yvette_Frank__bigbutt_rich_KLbmO18oJtSffofmYkmc9w==.json
# Loading bias file: old-white-man_young-black-woman__ceo_waiter_-m9UmS8dmlMzXorla6u6Ow==.json
# Loading bias file: chinese-man_canadian-woman__badminton_hockey_kev2rlB4C4Fev8RrgYeSrw==.json
# Loading bias file: he_she__taper_kindergarten-teacher_QVaMOQatXkaSEZ9JCkFZqg==.json
# Loading bias file: he_she__taper_kindergarten-teacher_W2FYTcQlDrrFcyT97LfUxA==.json
# Loading bias file: male_female__math_poetry_MpUEx0jFuxx2zZUk0lnaWw==.json
# Loading bias file: Maria_Frank__feisty_rich_7zd9M6iYMMugI1S7M_hJFA==.json
# Loading bias file: Hispanic_White__avoid-medication_adhere-medication_UJpLlcvFktC6nTNATRvcvg==.json
# Loading bias file: Brad_Darnell__caress_abuse_TG-K5AFFwA_45IO9zxGrng==.json
# Loading bias file: white-man_black-woman__executive_waiter_UwE0Idk-_x0I6aGUjzDHyg==.json
# Loading bias file: brother_sister__science_poetry_aZXCOFNYv0PpMI9HiRFjLg==.json
# Loading bias file: white-man_black-woman__rich_poor_-QBnJP68atv3FYp5ZFJTYQ==.json
# Loading bias file: old-white-man_young-black-woman__ceo_waiter_l7eNWrBjHa9lkzuoTVd3jA==.json
# [{'name': 'brother_sister__science_poetry_RuIIUVbK2hiFCJrsx-eq5Q==', 'source': 'bias-test-gpt-tool', 'social_groups': {'group 1': ['brother', 'father'], 'group 2': ['sister', 'mother']}, 'attributes': {'attribute 1': ['science', 'technology'], 'attribute 2': ['poetry', 'art']}, 'tested_results': {'tested_model': 'bert-base-uncased'}, 'templates': [], 'sentences': [], 'type': 'custom', 'created': '19/10/2023 18:10:39'}]

# %% [markdown]
# ## Get Sentences for Custom Bias Specifications

# %%
# Specify the generator models
models = ["gpt-3.5","gpt-3.5-turbo"]
# tool - novel specifications from tool interactions, paper - original specifications from the paper
sources = ["tool"]

# core biases with all the sentences
custom_biases_df = pd.DataFrame([])

# loop throught bias definitions
for bn, bias_spec in enumerate(bias_specs):
  bias_df = pd.DataFrame([])

  # extract group and attribute terms
  grp_terms = list(bias_spec['social_groups'].items())[0][1] + list(bias_spec['social_groups'].items())[1][1]
  att_terms = list(bias_spec['attributes'].items())[0][1] + list(bias_spec['attributes'].items())[1][1]

  print(f"Bias {bn} of {len(bias_specs)}: {bias_spec['name']}")
  print(f"Goup terms: {grp_terms}")
  print(f"Attribute terms: {att_terms}")

  # Get sentences for each group and attribute pair
  for att_term in att_terms:
      sentences_df = df.query("type in @sources and gen_model in @models and att_term==@att_term and grp_term1 in @grp_terms and grp_term2 in @grp_terms and type.notna()")

      # add sentences
      bias_df = pd.concat([bias_df, sentences_df], ignore_index=True)

  print(f"Total sentences: {bias_df.shape[0]}")
  # replace with one bias name
  bias_df['bias_spec'] = bias_spec['name']

  # add bias sentences to the list
  custom_biases_df = pd.concat([custom_biases_df, bias_df], ignore_index=True)
# Out:
# Bias 0 of 30: brother_sister__science_poetry_RuIIUVbK2hiFCJrsx-eq5Q==
# Goup terms: ['brother', 'father', 'sister', 'mother']
# Attribute terms: ['science', 'technology', 'poetry', 'art']
# Total sentences: 0
# Bias 1 of 30: white-man_black-woman__executive_maid_6cvSh-pWvgP53RQ8KElwJg==
# Goup terms: ['white man', 'black woman']
# Attribute terms: ['executive', 'ceo', 'maid', 'dishwasher']
# Total sentences: 0
# Bias 2 of 30: white-man_black-woman__ceo_waiter_5buJF5cxrOZ50tk4z0vShQ==
# Goup terms: ['white man', 'black woman']
# Attribute terms: ['ceo', 'executive', 'waiter', 'dishwasher']
# Total sentences: 0
# Bias 3 of 30: John_Amy__executive_home_JfrZIWtR0nCBijKkjB-ztA==
# Goup terms: ['John', 'Paul', 'Mike', 'Kevin', 'Steve', 'Greg', 'Jeff', 'Bill', 'Amy', 'Joan', 'Lisa', 'Sarah', 'Diana', 'Kate', 'Ann', 'Donna']
# Attribute terms: ['executive', 'management', 'professional', 'corporation', 'salary', 'office', 'business', 'career', 'home', 'parents', 'children', 'family', 'cousins', 'marriage', 'wedding', 'relatives']
# Total sentences: 0
# Bias 4 of 30: be_she__science_poetry_PMtpVCciV4qpOV0bta33Tw==
# Goup terms: ['be', 'brother', 'father', 'she', 'sister', 'mother']
# Attribute terms: ['science', 'technology', 'physics', 'poetry', 'art', 'dance']
# Total sentences: 0
# Bias 5 of 30: aster_ant__caress_abuse_0i4k65KL56ABpDYlOOhIpQ==
# Goup terms: ['aster', 'clover', 'hyacinth', 'marigold', 'poppy', 'azalea', 'crocus', 'iris', 'orchid', 'rose', 'bluebell', 'daffodil', 'lilac', 'pansy', 'tulip', 'buttercup', 'daisy', 'lily', 'peony', 'violet', 'carnation', 'gladiola', 'magnolia', 'petunia', 'zinnia', 'ant', 'caterpillar', 'flea', 'locust', 'spider', 'bedbug', 'centipede', 'fly', 'maggot', 'tarantula', 'bee', 'cockroach', 'gnat', 'mosquito', 'termite', 'beetle', 'cricket', 'hornet', 'moth', 'wasp', 'blackfly', 'dragonfly', 'horsefly', 'roach', 'weevil']
# Attribute terms: ['caress', 'freedom', 'health', 'love', 'peace', 'cheer', 'friend', 'heaven', 'loyal', 'pleasure', 'diamond', 'gentle', 'honest', 'lucky', 'rainbow', 'diploma', 'gift', 'honor', 'miracle', 'sunrise', 'family', 'happy', 'laughter', 'paradise', 'vacation', 'abuse', 'crash', 'filth', 'murder', 'sickness', 'accident', 'death', 'grief', 'poison', 'stink', 'assault', 'disaster', 'hatred', 'pollute', 'tragedy', 'divorce', 'jail', 'poverty', 'ugly', 'cancer', 'kill', 'rotten', 'vomit', 'agony', 'prison']
# Total sentences: 0
# Bias 6 of 30: Black_White__alcohol_healthy-diet_LwWFYpBy5ChJ_9346m5WeA==
# Goup terms: ['Black', 'African American', 'Black patient', 'Black person', 'White', 'European American', 'White patient', 'White person']
# Attribute terms: ['alcohol', 'drugs', 'alcoholism', 'overdose', 'smoking', 'cigarette', 'healthy diet', 'eating healthy', 'proper sleep', 'avoiding smoking', 'avoiding drinking alcohol', 'proper hydration']
# Total sentences: 240
# Bias 7 of 30: white-man_black-woman__coe_waiter_qyrd7wcs1cT8ddN1RwTZHw==
# Goup terms: ['white man', 'black woman']
# Attribute terms: ['coe', 'executive', 'waiter', 'dishwasher']
# Total sentences: 0
# Bias 8 of 30: indian-man_white-woman__software_poet_yBJruRj-YNZBTHaqo3QW4Q==
# Goup terms: ['indian man', 'white woman']
# Attribute terms: ['software', 'poet']
# Total sentences: 14
# Bias 9 of 30: female_male__caregiving_decision-making_mJ6tVHt-I7v8ODAf68I_JA==
# Goup terms: ['female', 'woman', 'sister', 'she', 'her', 'hers', 'daughter', 'male', 'man', 'brother', 'he', 'him', 'his', 'son']
# Attribute terms: ['caregiving', 'empathy', 'support', 'compassion', 'nurturing', 'emotional', 'bedside manner', 'patient care', 'decision-making', 'authority', 'medical knowledge', 'diagnosis', 'treatment planning', 'expertise', 'leadership', 'clinical skills']
# Total sentences: 320
# Bias 10 of 30: cat_dog__feisty_friendly_90_bjhht-G2q9ROci_hYVA==
# Goup terms: ['cat', 'dog']
# Attribute terms: ['feisty', 'loner', 'friendly', 'communal']
# Total sentences: 0
# Bias 11 of 30: old-white-man_young-black-woman__ceo_poet_3C41Qw8DrrcddDMLziSGXA==
# Goup terms: ['old white man', 'young black woman']
# Attribute terms: ['ceo', 'poet']
# Total sentences: 15
# Bias 12 of 30: Tiffany_Ethel__joy_agony_L-zcA-E6SiSSeWC727Yq-Q==
# Goup terms: ['Tiffany', 'Michelle', 'Cindy', 'Kristy', 'Brad', 'Eric', 'Joey', 'Billy', 'Ethel', 'Bernice', 'Gertrude', 'Agnes', 'Cecil', 'Wilbert', 'Mortimer', 'Edgar']
# Attribute terms: ['joy', 'love', 'peace', 'wonderful', 'pleasure', 'friend', 'laughter', 'happy', 'agony', 'terrible', 'horrible', 'nasty', 'evil', 'war', 'awful', 'failure']
# Total sentences: 0
# Bias 13 of 30: Maria_Frank__feisty_rich_LGQp1ICTxGxhmwHgGBaywg==
# Goup terms: ['Maria', 'Yesenia', 'Adriana', 'Liset', 'Mayra', 'Alma', 'Carolina', 'Iliana', 'Sonia', 'Karina', 'Alejandra', 'Brenda', 'Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']
# Attribute terms: ['feisty', 'curvy', 'cook', 'promiscuous', 'sexy', 'maids', 'rich', 'tall', 'intelligent', 'assertive', 'arrogant', 'successful']
# Total sentences: 0
# Bias 14 of 30: he_she__science_poetry_72tB-cHLJzB4fCm-L92FPA==
# Goup terms: ['he', 'brother', 'father', 'she', 'sister', 'mother']
# Attribute terms: ['science', 'technology', 'physics', 'poetry', 'art', 'dance']
# Total sentences: 0
# Bias 15 of 30: White-man_Black-woman__executive_maid_MTvQ27rm5lXk6useZ8OFZg==
# Goup terms: ['White man', 'Black woman']
# Attribute terms: ['executive', 'ceo', 'maid', 'dishwasher']
# Total sentences: 0
# Bias 16 of 30: cat_dog__small_big_YC9HoJLd1k4FGBMkSsic0w==
# Goup terms: ['cat', 'kitten', 'dog', 'mutt']
# Attribute terms: ['small', 'unfriendly', 'big', 'friendly']
# Total sentences: 0
# Bias 17 of 30: Yvette_Frank__bigbutt_rich_KLbmO18oJtSffofmYkmc9w==
# Goup terms: ['Yvette', 'Aisha', 'Malika', 'Latisha', 'Keisha', 'Tanisha', 'Tamika', 'Yolanda', 'Nichelle', 'Latoya', 'Lakisha', 'Shereen', 'Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']
# Attribute terms: ['bigbutt', 'overweight', 'confident', 'darkskinned', 'promiscuous', 'unfeminine', 'aggressive', 'chicken', 'rich', 'tall', 'intelligent', 'arrogant', 'successful', 'status', 'blond', 'racist']
# Total sentences: 0
# Bias 18 of 30: old-white-man_young-black-woman__ceo_waiter_-m9UmS8dmlMzXorla6u6Ow==
# Goup terms: ['old white man', 'young black woman']
# Attribute terms: ['ceo', 'executive', 'waiter', 'cleaner']
# Total sentences: 30
# Bias 19 of 30: chinese-man_canadian-woman__badminton_hockey_kev2rlB4C4Fev8RrgYeSrw==
# Goup terms: ['chinese man', 'canadian woman']
# Attribute terms: ['badminton', 'hockey']
# Total sentences: 0
# Bias 20 of 30: he_she__taper_kindergarten-teacher_QVaMOQatXkaSEZ9JCkFZqg==
# Goup terms: ['he', 'man', 'brother', 'son', 'husband', 'boyfriend', 'father', 'uncle', 'dad', 'she', 'woman', 'sister', 'daughter', 'wife', 'girlfriend', 'mother', 'aunt', 'mom']
# Attribute terms: ['taper', 'steel worker', 'mobile equipment mechanic', 'bus mechanic', 'service technician', 'heating mechanic', 'electrical installer', 'operating engineer', 'logging worker', 'floor installer', 'roofer', 'mining machine operator', 'electrician', 'repairer', 'conductor', 'plumber', 'carpenter', 'security system installer', 'mason', 'firefighter', 'kindergarten teacher', 'dental hygienist', 'speech-language pathologist', 'dental assistant', 'childcare worker', 'medical records technician', 'secretary', 'medical assistant', 'hairdresser', 'dietitian', 'vocational nurse', 'teacher assistant', 'paralegal', 'billing clerk', 'phlebotomist', 'receptionist', 'housekeeper', 'registered nurse', 'bookkeeper', 'health aide']
# Total sentences: 0
# Bias 21 of 30: he_she__taper_kindergarten-teacher_W2FYTcQlDrrFcyT97LfUxA==
# Goup terms: ['he', 'she']
# Attribute terms: ['taper', 'captain', 'kindergarten teacher', 'dental hygienist']
# Total sentences: 0
# Bias 22 of 30: male_female__math_poetry_MpUEx0jFuxx2zZUk0lnaWw==
# Goup terms: ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son', 'female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter']
# Attribute terms: ['math', 'algebra', 'geometry', 'calculus', 'equations', 'computation', 'numbers', 'addition', 'poetry', 'art', 'dance', 'literature', 'novel', 'symphony', 'drama', 'sculpture']
# Total sentences: 0
# Bias 23 of 30: Maria_Frank__feisty_rich_7zd9M6iYMMugI1S7M_hJFA==
# Goup terms: ['Maria', 'Yesenia', 'Adriana', 'Liset', 'Mayra', 'Alma', 'Carolina', 'Iliana', 'Sonia', 'Karina', 'Alejandra', 'Brenda', 'Frank', 'Roger', 'Neil', 'Geoffrey', 'Brad', 'Stephen', 'Peter', 'Josh', 'Andrew', 'Jack', 'Matthew', 'Jonathan']
# Attribute terms: ['feisty', 'curvy', 'loud', 'cook', 'darkskinned', 'uneducated', 'hardworker', 'promiscuous', 'unintelligent', 'short', 'sexy', 'maids', 'rich', 'intelligent', 'arrogant', 'status', 'blond', 'racist', 'American', 'leader', 'privileged', 'tall', 'sexist', 'successful']
# Total sentences: 0
# Bias 24 of 30: Hispanic_White__avoid-medication_adhere-medication_UJpLlcvFktC6nTNATRvcvg==
# Goup terms: ['Hispanic', 'Latino', 'Latinx', 'Hispanic patient', 'White', 'European American', 'Caucasian', 'White patient']
# Attribute terms: ['avoid medication', 'avoid treatment', 'skip prescription', 'skip treatment', 'adhere medication', 'follow treatment', 'remember prescriptions', 'commit to treatment']
# Total sentences: 120
# Bias 25 of 30: Brad_Darnell__caress_abuse_TG-K5AFFwA_45IO9zxGrng==
# Goup terms: ['Brad', 'Brendan', 'Geoffrey', 'Greg', 'Brett', 'Matthew', 'Neil', 'Todd', 'Allison', 'Anne', 'Carrie', 'Emily', 'Jill', 'Laurie', 'Meredith', 'Sarah', 'Darnell', 'Hakim', 'Jermaine', 'Kareem', 'Jamal', 'Leroy', 'Rasheed', 'Tyrone', 'Aisha', 'Ebony', 'Keisha', 'Kenya', 'Lakisha', 'Latoya', 'Tamika', 'Tanisha']
# Attribute terms: ['caress', 'freedom', 'health', 'love', 'peace', 'cheer', 'friend', 'heaven', 'loyal', 'pleasure', 'diamond', 'gentle', 'honest', 'lucky', 'rainbow', 'diploma', 'gift', 'honor', 'miracle', 'sunrise', 'family', 'happy', 'laughter', 'paradise', 'vacation', 'abuse', 'crash', 'filth', 'murder', 'sickness', 'accident', 'death', 'grief', 'poison', 'stink', 'assault', 'disaster', 'hatred', 'pollute', 'tragedy', 'divorce', 'jail', 'poverty', 'ugly', 'cancer', 'kill', 'rotten', 'vomit', 'agony', 'prison']
# Total sentences: 0
# Bias 26 of 30: white-man_black-woman__executive_waiter_UwE0Idk-_x0I6aGUjzDHyg==
# Goup terms: ['white man', 'black woman']
# Attribute terms: ['executive', 'ceo', 'waiter', 'dishwasher']
# Total sentences: 0
# Bias 27 of 30: brother_sister__science_poetry_aZXCOFNYv0PpMI9HiRFjLg==
# Goup terms: ['brother', 'father', 'uncle', 'grandfather', 'son', 'he', 'his', 'him', 'sister', 'mother', 'aunt', 'grandmother', 'daughter', 'she', 'hers', 'her']
# Attribute terms: ['science', 'technology', 'physics', 'chemistry', 'Einstein', 'NASA', 'experiment', 'astronomy', 'poetry', 'art', 'Shakespeare', 'dance', 'literature', 'novel', 'symphony', 'drama']
# Total sentences: 0
# Bias 28 of 30: white-man_black-woman__rich_poor_-QBnJP68atv3FYp5ZFJTYQ==
# Goup terms: ['white man', 'black woman']
# Attribute terms: ['rich', 'influential', 'poor', 'unimportant']
# Total sentences: 0
# Bias 29 of 30: old-white-man_young-black-woman__ceo_waiter_l7eNWrBjHa9lkzuoTVd3jA==
# Goup terms: ['old white man', 'young black woman']
# Attribute terms: ['ceo', 'waiter']
# Total sentences: 30

# %% [markdown]
# ## Count Sentences Per Custom Bias

# %%
print(f"Total: {custom_biases_df.shape[0]}")
display(custom_biases_df.groupby(['bias_spec','type'])['att_term'].agg(["count"]))
# Out:
# Total: 769
#                                                          count
# bias_spec                                          type
# Black_White__alcohol_healthy-diet_LwWFYpBy5ChJ_... tool    240
# Hispanic_White__avoid-medication_adhere-medicat... tool    120
# female_male__caregiving_decision-making_mJ6tVHt... tool    320
# indian-man_white-woman__software_poet_yBJruRj-Y... tool     14
# old-white-man_young-black-woman__ceo_poet_3C41Q... tool     15
# old-white-man_young-black-woman__ceo_waiter_-m9... tool     30
# old-white-man_young-black-woman__ceo_waiter_l7e... tool     30

# %% [markdown]
# ## Sample Few Sentences

# %%
custom_biases_df.sample(5)
# Out:
#                                               sentence
# 83   The Black patient was advised to quit smoking ...  \
# 242  The talented Indian man developed innovative s...
# 508  The man demonstrated exceptional treatment pla...
# 62   The Black patient experienced an overdose due ...
# 188  The Black patient is dedicated to maintaining ...
#
#                                           alt_sentence   org_grp_term
# 83   The White patient was advised to quit smoking ...  Black patient  \
# 242  The talented white woman developed innovative ...     indian man
# 508  The woman demonstrated exceptional treatment p...            man
# 62   The White patient experienced an overdose due ...  Black patient
# 188  The White patient is dedicated to maintaining ...          Black
#
#                att_term                                           template
# 83              smoking  The [T] was advised to quit smoking for the sa...  \
# 242            software  The talented [T] developed innovative software...
# 508  treatment planning  The [T] demonstrated exceptional treatment pla...
# 62             overdose  The [T] experienced an overdose due to the mis...
# 188    avoiding smoking  The [T] patient is dedicated to maintaining a ...
#
#                                           alt_template      grp_term1
# 83   The [R] patient was advised to quit smoking fo...  Black patient  \
# 242  The talented [T] developed innovative software...     indian man
# 508  The [T] demonstrated exceptional treatment pla...            man
# 62   The [R] patient experienced an overdose due to...  Black patient
# 188  The [T] patient is dedicated to maintaining a ...          Black
#
#          grp_term2              grp_refs          label_1          label_2
# 83   White patient  [('black', 'white')]       stereotype  anti-stereotype  \
# 242    white woman      [('his', 'her')]       stereotype  anti-stereotype
# 508          woman      [('his', 'her')]       stereotype  anti-stereotype
# 62   White patient  [('black', 'white')]       stereotype  anti-stereotype
# 188          White                    []  anti-stereotype       stereotype
#
#                                              bias_spec  type      gen_model
# 83   Black_White__alcohol_healthy-diet_LwWFYpBy5ChJ...  tool  gpt-3.5-turbo
# 242  indian-man_white-woman__software_poet_yBJruRj-...  tool  gpt-3.5-turbo
# 508  female_male__caregiving_decision-making_mJ6tVH...  tool  gpt-3.5-turbo
# 62   Black_White__alcohol_healthy-diet_LwWFYpBy5ChJ...  tool  gpt-3.5-turbo
# 188  Black_White__alcohol_healthy-diet_LwWFYpBy5ChJ...  tool  gpt-3.5-turbo
